# %%
import pandas as pd
import numpy as np
import glob

# %%
df = pd.read_csv('behavioralData/ColorWM_103_2_SUP_.txt', 
            delimiter=',')
df = df.rename(columns=lambda x: x.strip())
df.columns
# Out:
# Index(['subject', 'session', 'target', 'StimLat', 'CurrentTask',
#        'TaskCondition', 'block', 'trial', 'LoadLevel', 'SetSize', 'ShownLocs',
#        'AllColors', 'ShownColors', 'ProbeMatch', 'ChosenProbeColor',
#        'CorrectProbeColor', 'ProbeLoc', 'probert', 'msecProbeRT', 'probeACC',
#        'response', 'error', 'matchCond'],
#       dtype='object')

# %%
df
# Out:
#      subject  session target StimLat  CurrentTask            TaskCondition  \
# 0        103        2    SUP    Left            1   SpatialChangeDetection
# 1        103        2    SUP    Left            1   SpatialChangeDetection
# 2        103        2    SUP    Left            1   SpatialChangeDetection
# 3        103        2    SUP    Left            1   SpatialChangeDetection
# 4        103        2    SUP    Left            1   SpatialChangeDetection
# ..       ...      ...    ...     ...          ...                      ...
# 571      103        2    SUP    Left            2                Precision
# 572      103        2    SUP    Left            2                Precision
# 573      103        2    SUP    Left            2                Precision
# 574      103        2    SUP    Left            2                Precision
# 575      103        2    SUP    Left            2                Precision
#
# ...

# %%
df.groupby('TaskCondition')['response'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
df = pd.read_csv('behavioralData/ColorWM_103_3_INF_.txt', 
            delimiter=',')
df = df.rename(columns=lambda x: x.strip())
df
# Out:
#      subject  session target StimLat  CurrentTask            TaskCondition  \
# 0        103        3    INF    Left            1   SpatialChangeDetection
# 1        103        3    INF    Left            1   SpatialChangeDetection
# 2        103        3    INF    Left            1   SpatialChangeDetection
# 3        103        3    INF    Left            1   SpatialChangeDetection
# 4        103        3    INF    Left            1   SpatialChangeDetection
# ..       ...      ...    ...     ...          ...                      ...
# 571      103        3    INF    Left            2                Precision
# 572      103        3    INF    Left            2                Precision
# 573      103        3    INF    Left            2                Precision
# 574      103        3    INF    Left            2                Precision
# 575      103        3    INF    Left            2                Precision
#
# ...
